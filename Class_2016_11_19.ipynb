# %% [markdown]
# # Pandas:

# %%
import pandas as pd

# %%
paises = pd.DataFrame(
    {'Poblacion' : [1e7, 4e7, 6e7], 'Idioma' : ['Portugues', 'Espaniol', 'Frances']},
    index=['Portugal', 'Espania', 'Italia'])

# %%
paises['1970'] = ['Dictadura', 'Dictadura','Democracia']

# %%
paises
# Out:
#              Idioma   Poblacion        1970
# Portugal  Portugues  10000000.0   Dictadura
# Espania    Espaniol  40000000.0   Dictadura
# Italia      Frances  60000000.0  Democracia

# %%
paises[['Idioma', 'Poblacion']]
# Out:
#              Idioma   Poblacion
# Portugal  Portugues  10000000.0
# Espania    Espaniol  40000000.0
# Italia      Frances  60000000.0

# %%
# We can reindex, which might create missing data (NaNs, empty cells)

with_nas = paises.reindex(['Portugal', 'Francia', 'Espania', 'Italia'])
with_nas

# %%
with_nas.fillna(value=0)
# Out:
#              Idioma   Poblacion        1970
# Portugal  Portugues  10000000.0   Dictadura
# Francia           0         0.0           0
# Espania    Espaniol  40000000.0   Dictadura
# Italia      Frances  60000000.0  Democracia

# %%
# We can fill them with a single value, with one per column, or with a method:

valores_por_defecto = {'Idioma' : 'Desconocido', 'Poblacion' : 0, '1970': 'Desconocido'}
with_nas.fillna(valores_por_defecto)
# Out:
#                Idioma   Poblacion         1970
# Portugal    Portugues  10000000.0    Dictadura
# Francia   Desconocido         0.0  Desconocido
# Espania      Espaniol  40000000.0    Dictadura
# Italia        Frances  60000000.0   Democracia

# %%
# None of these methods modify the DataFrame in place unless we specify
with_nas
# Out:
#              Idioma   Poblacion        1970
# Portugal  Portugues  10000000.0   Dictadura
# Francia         NaN         NaN         NaN
# Espania    Espaniol  40000000.0   Dictadura
# Italia      Frances  60000000.0  Democracia

# %%
with_nas.fillna(method='ffill')
# Out:
#              Idioma   Poblacion        1970
# Portugal  Portugues  10000000.0   Dictadura
# Francia   Portugues  10000000.0   Dictadura
# Espania    Espaniol  40000000.0   Dictadura
# Italia      Frances  60000000.0  Democracia

# %%
with_nas.fillna(method='bfill')
# Out:
#              Idioma   Poblacion        1970
# Portugal  Portugues  10000000.0   Dictadura
# Francia    Espaniol  40000000.0   Dictadura
# Espania    Espaniol  40000000.0   Dictadura
# Italia      Frances  60000000.0  Democracia

# %%
with_nas
# Out:
#              Idioma   Poblacion        1970
# Portugal  Portugues  10000000.0   Dictadura
# Francia         NaN         NaN         NaN
# Espania    Espaniol  40000000.0   Dictadura
# Italia      Frances  60000000.0  Democracia

# %%
with_nas['Poblacion']['Francia'] = 65e6
# Out:
# /home/dani/dev/master-data-science/06_python_for_data_science/env/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
with_nas
# Out:
#              Idioma   Poblacion        1970
# Portugal  Portugues  10000000.0   Dictadura
# Francia         NaN  65000000.0         NaN
# Espania    Espaniol  40000000.0   Dictadura
# Italia      Frances  60000000.0  Democracia

# %% [markdown]
# ### The axis argument
#
# It will come up often. Tells pandas whether to apply an operation horizontally or vertically.

# %%
with_nas.dropna(axis=1)
# Out:
#            Poblacion
# Portugal  10000000.0
# Francia   65000000.0
# Espania   40000000.0
# Italia    60000000.0

# %%
with_nas.dropna(how='all')
# Out:
#              Idioma   Poblacion        1970
# Portugal  Portugues  10000000.0   Dictadura
# Francia         NaN  65000000.0         NaN
# Espania    Espaniol  40000000.0   Dictadura
# Italia      Frances  60000000.0  Democracia

# %%
with_nas.describe()
# Out:
#           Poblacion
# count  4.000000e+00
# mean   4.375000e+07
# std    2.495830e+07
# min    1.000000e+07
# 25%    3.250000e+07
# 50%    5.000000e+07
# 75%    6.125000e+07
# max    6.500000e+07

# %%
type(with_nas.describe())
# Out:
# pandas.core.frame.DataFrame

# %%
with_nas.count()
# Out:
# Idioma       3
# Poblacion    4
# 1970         3
# dtype: int64

# %% [markdown]
# ### Reading data from files

# %%
# !ls
# Out:
# Class_2016_11_18.ipynb	Class_2016_11_19.ipynb

# %%
# !ls ~/Data
# Out:
# ls: cannot access /home/dani/Data: No such file or directory

# %%
# This is the path in the masters' vm

path_to_data = '/home/dsc/Data'

# %%
# This is it in my machine:

path_to_data = '/home/dani/dev/master-data-science/data'

# %%
! ls {path_to_data}/opentraveldata/optd_aircraft.csv
# Out:
# /home/dani/dev/master-data-science/data/opentraveldata/optd_aircraft.csv

# %%
"%s/opentraveldata/optd_aircraft.csv" % path_to_data
# Out:
# '/home/dani/dev/master-data-science/data/opentraveldata/optd_aircraft.csv'

# %%
path = "%s/opentraveldata/optd_aircraft.csv" % path_to_data

# %%
open(path)
# Out:
# <open file '/home/dani/dev/master-data-science/data/opentraveldata/optd_aircraft.csv', mode 'r' at 0x7f66d9b14780>

# %%
data_file = open(path)

# %%
type(data_file)
# Out:
# file

# %%
data_file.next()
# Out:
# 'iata_code^manufacturer^model^iata_group^iata_category^icao_code^nb_engines^aircraft_type\n'

# %%
data_file.next()
# Out:
# '100^Fokker^100^100^2J^F100^2^J\n'

# %%
type(data_file.next())
# Out:
# str

# %%
data_file.next()
# Out:
# '14Z^BAe^146 Freighter (-300QT & QC)^14F^4J^B463^4^J\n'

# %%
data_file.seek(0)
data_file.next()
# Out:
# 'iata_code^manufacturer^model^iata_group^iata_category^icao_code^nb_engines^aircraft_type\n'

# %%
data_file.seek(0)
header = data_file.next()
header.split('^')
# Out:
# ['iata_code',
#  'manufacturer',
#  'model',
#  'iata_group',
#  'iata_category',
#  'icao_code',
#  'nb_engines',
#  'aircraft_type\n']

# %% [markdown]
# ### Exercise
#
# How many models are there in the file `optd_aircraft.csv` that have two engines?
#
# Do it without pandas so you'll appreciate how awesome pandas is ;P

# %%
contador = 0

data_file.seek(0)
for line in data_file:
    elements = line.split('^')
    nb_engines = elements[-2]
    
    if nb_engines == '2':
        contador += 1 # estrictamente equivalente a contador = contador + 1

contador
# Out:
# 241

# %% [markdown]
# ## Reading files into Dataframes

# %%
aircraft = pd.read_csv(path, '^')
aircraft.head(5)
aircraft.sample(5)
# Out:
#     iata_code manufacturer             model iata_group iata_category  \
# 83        73S       Boeing  737-200 Advanced        73F            2J
# 32        340       Airbus              A340        NaN           NaN
# 155       ABY       Airbus         A300-600F        ABF            2J
# 327       ER4      Embraer           ERJ 145        ERJ            2J
# 295       DF7     Dassault         Falcon 7X        DFL            3J
#
#     icao_code  nb_engines aircraft_type
# 83       B737         2.0             J
# 32        NaN         NaN           NaN
# 155      A306         2.0             J
# 327      E145         2.0             J
# 295      FA7X         3.0             J

# %%
# Exercise as before: How many 2-engine models?

num_correcto = aircraft['nb_engines'] == 2
dos_motores = aircraft[num_correcto]

dos_motores.count()['nb_engines']
# Out:
# 241

# %%
# Another way:

(aircraft['nb_engines'] == 2).sum()

# And another:

len(aircraft[aircraft['nb_engines'] == 2])
# Out:
# 241

# %%
# We can intersect (&) boolean Series and use that to select within the dataframe:

esairbus_tiene2motores = (aircraft['manufacturer'] == 'Airbus') & (aircraft['nb_engines'] == 2)

# %%
aircraft[esairbus_tiene2motores].sample(5)
# Out:
#     iata_code manufacturer               model iata_group iata_category  \
# 13        318       Airbus                A318        32S            2J
# 31        33X       Airbus  A330-200 Freighter        33F            2J
# 21        32A       Airbus    A320 (sharklets)        32S            2J
# 25        32F       Airbus      A320 Freighter        32F            2J
# 150       AB6       Airbus            A300-600        AB3            2J
#
#     icao_code  nb_engines aircraft_type
# 13       A318         2.0             J
# 31       A332         2.0             J
# 21       A320         2.0             J
# 25       A320         2.0             J
# 150      A306         2.0             J

# %%
tienen_dos_motores = aircraft['nb_engines'] == 2

# %%
not tienen_dos_motores
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-c7a3e2dd54a3> in <module>()
# ----> 1 not tienen_dos_motores
#
# /home/dani/dev/master-data-science/06_python_for_data_science/env/local/lib/python2.7/site-packages/pandas/core/generic.pyc in __nonzero__(self)
#     890         raise ValueError("The truth value of a {0} is ambiguous. "
#     891                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 892                          .format(self.__class__.__name__))
#     893
#     894     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# Element-wise not:

no_tienen_dos_motores = ~tienen_dos_motores

# %%
# We were using a range index. Much better to specify which column is a unique designator:

aircraft_bien = pd.read_csv(path, sep='^', index_col='iata_code')

# %%
print aircraft.index.name
print aircraft_bien.index.values[:20]
print len(aircraft.index.unique())
# Out:
# None
# ['100' '141' '142' '143' '146' '14F' '14X' '14Y' '14Z' '19D' '310' '312'
#  '313' '318' '319' '31F' '31W' '31X' '31Y' '320']
# 457

# %%
# Indexes are immutable:

aircraft.index['100'] = 'coso'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-119-ace18c772142> in <module>()
# ----> 1 aircraft.index['100'] = 'coso'
#
# /home/dani/dev/master-data-science/06_python_for_data_science/env/local/lib/python2.7/site-packages/pandas/indexes/base.pyc in __setitem__(self, key, value)
#    1243
#    1244     def __setitem__(self, key, value):
# -> 1245         raise TypeError("Index does not support mutable operations")
#    1246
#    1247     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %% [markdown]
# ### The `.str` attribute
#
# It contains a lot of convenient vectorized string functions.

# %%
fabricantes = aircraft_bien['manufacturer']
fabricantes.str.lower()[:5]
# Out:
# iata_code
# 100    fokker
# 141       bae
# 142       bae
# 143       bae
# 146       bae
# Name: manufacturer, dtype: object

# %%
aircraft_bien[fabricantes.str.startswith('P').fillna(False)]
# Out:
#            manufacturer                         model iata_group  \
# iata_code
# P18        Piaggio Aero                P180 Avanti II        P18
# PA1               Piper    Piper single piston engine        PAG
# PA2               Piper     Piper twin piston engines        PAG
# PAG               Piper          Piper light aircraft        NaN
# PAT               Piper  Piper twin turboprop engines        PAG
# PL2             Pilatus                         PC-12        PL2
# PL6             Pilatus             PC-6 Turbo Porter        PL6
# PN6          Partenavia                          P.68        PN6
#
#           iata_category icao_code  nb_engines aircraft_type
# iata_code
# P18                  2T      P180         2.0             T
# PA1                  1P         *         1.0             P
# PA2                  2P         *         2.0             P
# PAG                 NaN       NaN         NaN           NaN
# PAT                  2T         *         2.0             T
# PL2                  1T      PC12         1.0             T
# PL6                  1T      PC6T         1.0             T
# PN6                  2P       P68         2.0             P

# %% [markdown]
# # Digression: Functional programming in Python
#
# [Functional programming](https://en.wikipedia.org/wiki/Functional_programming) is a programming paradigm that uses functions, and specifically *pure* functions, as the core element with which to build programs.
#
# A key to functional programming are *higher order functions*, that is, functions that take other functions as arguments or that return other functions. The essential ones are *map()* and *reduce()*

# %% [markdown]
# #### Map
#
# `map()` takes a function and an iterable and returns an iterable that is the result of applying the function to each element of the iterable

# %%
enteros = [0, 1, 2, 3, 4]

def alcuadrado(num): return num ** 2

cuadrados = map(alcuadrado, enteros)
cuadrados
# Out:
# [0, 1, 4, 9, 16]

# %% [markdown]
# #### Reduce
#
# `reduce()` also takes a function f and an iterable. f takes two arguments and returns one value of the same type.
#
# `reduce()` applies function f to the first 2 elements of the iterable, then to the result of that application and to the next element of the iterable, and so on until it has only one element, which it returns.

# %%
def suma_2_numeros(num_1, num_2): return num_1 + num_2

reduce(suma_2_numeros, enteros)
# Out:
# 10

# %%
# Exercise: Implement a function maximo() as a reduce
# Ie, find the maximum number in a list using reduce().

# Do NOT use max()! where'd be the fun in that????

lista = [1,32,576,56,4,3,2,3]

def g(a, b): 
    if a > b:
        return a
    else: 
        return b

maximo = reduce(g, lista)
maximo
# Out:
# 576

# %%
# Do not worry too much about this: it's a look at the insides of 
# reduce() so you see it's recursive

def mireduce(func, lista):
    if len(lista) == 0: return None
    elif len(lista) == 1: return lista[0]
    else:
        return func(lista[0], mireduce(func, lista[1:]))

# %%
mireduce(suma_2_numeros, cuadrados)
# Out:
# 30

# %%
def h(a): return a % 2 == 0

print cuadrados
filter(h, cuadrados)
# Out:
# [0, 1, 4, 9, 16]
# [0, 4, 16]

# %% [markdown]
# #### Filter
#
# it's another very commonly used higher order function that takes a boolean function and a list.

# %%
filter(lambda x: x % 2 == 0, cuadrados)

# %% [markdown]
# #### Anonymous functions in Python:
#
# Specified with the lambda keyword

# %%
# These 2 are strictly equivalent

def suma_2_numeros(num_1, num_2): return num_1 + num_2
lambda x, y: x + y

# These 2 too

def alcuadrado(num): return num ** 2
lambda x: x ** 2
# Out:
# <function __main__.<lambda>>

# %%
# Forma retorcidilla de hacerlo
alcuadrado = lambda x: x ** 2

# %%
alcuadrado(5)
# Out:
# 25

# %%
reduce(suma_2_numeros, cuadrados) == reduce(lambda x, y: x + y, cuadrados)
# Out:
# True

# %% [markdown]
# ## Apply to dataframes:

# %%
aircraft_bien['nb_engines'].map(alcuadrado).sample(5)
# Out:
# iata_code
# TU3    4.0
# BEH    4.0
# 73E    4.0
# DHF    NaN
# L49    NaN
# Name: nb_engines, dtype: float64

# %%
# The prevous one is not super useful because we can 
# square elements in a Series easily, but it gives us 
# tremendous flexibility if we want to do something 
# a little more complicated.

(aircraft_bien['nb_engines'] ** 2).sample(5)
# Out:
# iata_code
# ANF    16.0
# M82     4.0
# 73N     4.0
# MIH     NaN
# FK7     4.0
# Name: nb_engines, dtype: float64

# %%
# pd.DataFrame.apply

# %% [markdown]
# # Group by
#
# Similar to its sql namesake.

# %%
groups = aircraft_bien.groupby('manufacturer')

# We can iterate over groups:

for k, group in groups:
    print k
    print group
# Out:
# ATR
#           manufacturer             model iata_group iata_category icao_code  \
# iata_code
# AT4                ATR  ATR 42-300 / 320        ATR            2T      AT43
# AT5                ATR        ATR 42-500        ATR            2T      AT45
# AT7                ATR            ATR 72        ATR            2T      AT72
# ATD                ATR        ATR 42-400        ATR            2T      AT44
# ATF                ATR  ATR 72 Freighter        ATF            2T      AT72
# ATR                ATR   ATR 42 / ATR 72        NaN           NaN       NaN
# ATZ                ATR  ATR 42 Freighter        ATZ            2T         *
#
#            nb_engines aircraft_type
# iata_code
# AT4               2.0             T
# AT5               2.0             T
# AT7               2.0             T
# ATD               2.0             T
# ATF               2.0             T
# ATR               NaN           NaN
# ATZ               2.0             T
# Aerospatiale / SNIAS
#                    manufacturer            model iata_group iata_category  \
# iata_code
# NDC        Aerospatiale / SNIAS  SN.601 Corvette        NDC            2J
# SSC        Aerospatiale / SNIAS         Concorde        NaN           NaN
#
#           icao_code  nb_engines aircraft_type
# iata_code
# NDC            S601         2.0             J
# SSC             NaN         NaN           NaN
# Agusta / AgustaWestland
#                       manufacturer  model iata_group iata_category icao_code  \
# iata_code
# AGH        Agusta / AgustaWestland  A-109        AGH             H      A109
#
#            nb_engines aircraft_type
# iata_code
# AGH               NaN             H
# AgustaWestland
#              manufacturer  model iata_group iata_category icao_code  \
# iata_code
# AWH        AgustaWestland  AW139        AWH            2T      A139
#
#            nb_engines aircraft_type
# iata_code
# AWH               2.0             T
# Airbus
#           manufacturer                         model iata_group iata_category  \
# iata_code
# 19D             Airbus                          A319        NaN           NaN
# 310             Airbus                          A310        NaN           NaN
# 312             Airbus                      A310-200        310            2J
# 313             Airbus                      A310-300        310            2J
# 318             Airbus                          A318        32S            2J
# 319             Airbus                          A319        32S            2J
# 31F             Airbus                         A310F        NaN           NaN
# 31W             Airbus              A319 (Sharklets)        NaN           NaN
# 31X             Airbus                     A310-200F        31F            2J
# 31Y             Airbus                     A310-300F        31F            2J
# 320             Airbus                  A320-100/200        32S            2J
# 321             Airbus                  A321-100/200        32S            2J
# 32A             Airbus              A320 (sharklets)        32S            2J
# 32B             Airbus              A321 (sharklets)        32S            2J
# 32C             Airbus              A318 (sharklets)        NaN           NaN
# 32D             Airbus              A319 (sharklets)        NaN           NaN
# 32F             Airbus                A320 Freighter        32F            2J
# 32X             Airbus                A321 Freighter        32X            2J
# 330             Airbus                          A330        NaN           NaN
# 332             Airbus                      A330-200        330            2J
# 333             Airbus                      A330-300        330            2J
# 33F             Airbus                A330 Freighter        NaN           NaN
# 33X             Airbus            A330-200 Freighter        33F            2J
# 340             Airbus                          A340        NaN           NaN
# 342             Airbus                      A340-200        340            4J
# 343             Airbus                      A340-300        340            4J
# 345             Airbus                      A340-500        340            4J
# 346             Airbus                      A340-600        340            4J
# 350             Airbus                          A350        NaN           NaN
# 351             Airbus                     A350-1000        350            2J
# 358             Airbus                      A350-800        350            2J
# 359             Airbus                      A350-900        350            2J
# 380             Airbus                          A380        NaN           NaN
# 388             Airbus                          A380        380            4J
# 38F             Airbus                         A380F        38F            4J
# AB2             Airbus                        A300B2        NaN           NaN
# AB3             Airbus                          A300        NaN           NaN
# AB4             Airbus                  A300B2/B4/C4        AB3            2J
# AB6             Airbus                      A300-600        AB3            2J
# ABB             Airbus             A300-600ST Beluga        ABF            2J
# ABF             Airbus                         A300F        NaN           NaN
# ABM             Airbus  A300-600 Mixed Configuration        NaN           NaN
# ABX             Airbus           A300C4/F4 Freighter        ABF            2J
# ABY             Airbus                     A300-600F        ABF            2J
#
#           icao_code  nb_engines aircraft_type
# iata_code
# 19D             NaN         NaN           NaN
# 310             NaN         NaN           NaN
# 312            A310         2.0             J
# 313            A310         2.0             J
# 318            A318         2.0             J
# 319            A319         2.0             J
# 31F             NaN         NaN           NaN
# 31W             NaN         NaN           NaN
# 31X            A310         2.0             J
# 31Y            A310         2.0             J
# 320            A320         2.0             J
# 321            A321         2.0             J
# 32A            A320         2.0             J
# 32B            A321         2.0             J
# 32C             NaN         NaN           NaN
# 32D             NaN         NaN           NaN
# 32F            A320         2.0             J
# 32X            A321         2.0             J
# 330             NaN         NaN           NaN
# 332            A332         2.0             J
# 333            A333         2.0             J
# 33F             NaN         NaN           NaN
# 33X            A332         2.0             J
# 340             NaN         NaN           NaN
# 342            A342         4.0             J
# 343            A343         4.0             J
# 345            A345         4.0             J
# 346            A346         4.0             J
# 350             NaN         NaN           NaN
# 351            ZZZZ         2.0             J
# 358            ZZZZ         2.0             J
# 359            ZZZZ         2.0             J
# 380             NaN         NaN           NaN
# 388            A388         4.0             J
# 38F            A388         4.0             J
# AB2             NaN         NaN           NaN
# AB3             NaN         NaN           NaN
# AB4            A30B         2.0             J
# AB6            A306         2.0             J
# ABB            A3ST         2.0             J
# ABF             NaN         NaN           NaN
# ABM             NaN         NaN           NaN
# ABX            A30B         2.0             J
# ABY            A306         2.0             J
# Aircraft Industries (LET)
#                         manufacturer            model iata_group  \
# iata_code
# L4F        Aircraft Industries (LET)  L-410 Freighter        L4F
#
#           iata_category icao_code  nb_engines aircraft_type
# iata_code
# L4F                  2T      L410         2.0             T
# Airtech
#           manufacturer   model iata_group iata_category icao_code  nb_engines  \
# iata_code
# CS5            Airtech  CN-235        CS5            2T      CN35         2.0
#
#           aircraft_type
# iata_code
# CS5                   T
# Antonov
#           manufacturer       model iata_group iata_category icao_code  \
# iata_code
# A22            Antonov       An-22        A22            4T      AN22
# A38            Antonov       An-38        A38            2T      AN38
# A58            Antonov      An-158        A58            2J      ZZZZ
# A5F            Antonov      An-225        A5F            6J      A225
# A81            Antonov  An-148-100        A81            2J      A148
# AN2            Antonov        An-2        NaN           NaN       NaN
#
#            nb_engines aircraft_type
# iata_code
# A22               4.0             T
# A38               2.0             T
# A58               2.0             J
# A5F               6.0             J
# A81               2.0             J
# AN2               NaN           NaN
# Antonow / Antonov
#                 manufacturer                    model iata_group  \
# iata_code
# A26        Antonow / Antonov                    An-26        AN6
# A28        Antonow / Antonov  An-28 / PZL Mielec M-28        A28
# A30        Antonow / Antonov                    An-30        AN6
# A32        Antonow / Antonov                    An-32        AN6
# A40        Antonow / Antonov                   An-140        A40
# A4F        Antonow / Antonov                   An-124        A4F
# AN4        Antonow / Antonov                    An-24        AN4
# AN6        Antonow / Antonov    An-26 / An-30 / An-32        NaN
# AN7        Antonow / Antonov            An-72 / An-74        AN7
# ANF        Antonow / Antonov                    An-12        ANF
#
#           iata_category icao_code  nb_engines aircraft_type
# iata_code
# A26                  2T      AN26         2.0             T
# A28                  2T      AN28         2.0             T
# A30                  2T      AN30         2.0             T
# A32                  2T      AN32         2.0             T
# A40                  2T      A140         2.0             T
# A4F                  4J      A124         4.0             J
# AN4                  2T      AN24         2.0             T
# AN6                 NaN       NaN         NaN           NaN
# AN7                  2J      AN72         2.0             J
# ANF                  4T      AN12         4.0             T
# Ayres
#           manufacturer              model iata_group iata_category icao_code  \
# iata_code
# ALM              Ayres  LM-200 Loadmaster        NaN           NaN       NaN
#
#            nb_engines aircraft_type
# iata_code
# ALM               NaN           NaN
# BAC
#           manufacturer              model iata_group iata_category icao_code  \
# iata_code
# B11                BAC         One Eleven        NaN           NaN       NaN
# B12                BAC     One Eleven 200        B11            2J      BA11
# B13                BAC     One Eleven 300        B11            2J      BA11
# B14                BAC  One Eleven 400/47        B11            2J      BA11
# B15                BAC     One Eleven 500        B11            2J      BA11
#
#            nb_engines aircraft_type
# iata_code
# B11               NaN           NaN
# B12               2.0             J
# B13               2.0             J
# B14               2.0             J
# B15               2.0             J
# BAe
#           manufacturer                                model iata_group  \
# iata_code
# 141                BAe                              146-100        146
# 142                BAe        BAE Systems 146-200 Passenger        146
# 143                BAe                              146-300        146
# 146                BAe                                  146        NaN
# 14F                BAe  146 Freighter (-100/200/300QT & QC)        NaN
# 14X                BAe          146 Freighter (-100QT & QC)        14F
# 14Y                BAe          146 Freighter (-200QT & QC)        14F
# 14Z                BAe          146 Freighter (-300QT & QC)        14F
# APF                BAe                        ATP Freighter        APF
# AR1                BAe                           Avro RJ100        ARJ
# AR7                BAe                            Avro RJ70        ARJ
# AR8                BAe                            Avro RJ85        ARJ
# ARJ                BAe             Avro RJ70 / RJ85 / RJ100        NaN
# ATP                BAe                                  ATP        ATP
# HS7                BAe                               HS.748        HS7
# J31                BAe                         Jetstream 31        JST
# J32                BAe                         Jetstream 32        JST
# J41                BAe                         Jetstream 41        JST
# JST                BAe               Jetstream 31 / 32 / 41        NaN
#
#           iata_category icao_code  nb_engines aircraft_type
# iata_code
# 141                  4J      B461         4.0             J
# 142                  4J      B462         4.0             J
# 143                  4J      B463         4.0             J
# 146                 NaN       NaN         NaN           NaN
# 14F                 NaN       NaN         NaN           NaN
# 14X                  4J      B461         4.0             J
# 14Y                  4J      B462         4.0             J
# 14Z                  4J      B463         4.0             J
# APF                  2T      ZZZZ         2.0             T
# AR1                  4J      RJ1H         4.0             J
# AR7                  4J      RJ70         4.0             J
# AR8                  4J      RJ85         4.0             J
# ARJ                 NaN       NaN         NaN           NaN
# ATP                  2T       ATP         2.0             T
# HS7                  2T      A748         2.0             T
# J31                  2T      JS31         2.0             T
# J32                  2T      JS32         2.0             T
# J41                  2T      JS41         2.0             T
# JST                 NaN       NaN         NaN           NaN
# Beechcraft
#           manufacturer                      model iata_group iata_category  \
# iata_code
# BE1         Beechcraft           1900/1900C/1900D        NaN           NaN
# BE2         Beechcraft          Beech twin piston        BEC            2P
# BE4         Beechcraft             Beechcraft 400        HBA            2J
# BE9         Beechcraft             Beechcraft C99        BE9            2T
# BEC         Beechcraft       Beech light aircraft        NaN           NaN
# BEF         Beechcraft  Beechcraft 1900 Freighter        BEF            2T
# BEH         Beechcraft                      1900D        BE1            2T
# BEP         Beechcraft         Beech singe piston        BEC            1P
# BES         Beechcraft                 1900/1900C        BE1            2T
# BET         Beechcraft       Beech twin turboprop        BEC            2T
#
#           icao_code  nb_engines aircraft_type
# iata_code
# BE1             NaN         NaN           NaN
# BE2               *         2.0             P
# BE4            BE40         2.0             J
# BE9            BE99         2.0             T
# BEC             NaN         NaN           NaN
# BEF            B190         2.0             T
# BEH            B190         2.0             T
# BEP               *         1.0             P
# BES            B190         2.0             T
# BET               *         2.0             T
# Bell Helicopter
#               manufacturer             model iata_group iata_category  \
# iata_code
# BH2        Bell Helicopter  Bell Helicopters        BH2             H
#
#           icao_code  nb_engines aircraft_type
# iata_code
# BH2               *         NaN             H
# Boeing
#           manufacturer                         model iata_group iata_category  \
# iata_code
# 703             Boeing                       707-300        707            4J
# 707             Boeing                       707/720        NaN           NaN
# 70F             Boeing                 707 Freighter        70F            4J
# 70M             Boeing                     707 Combi        70M            4J
# 717             Boeing                           717        717            2J
# 721             Boeing                       727-100        727            3J
# 722             Boeing                       727-200        727            3J
# 727             Boeing                           727        NaN           NaN
# 72A             Boeing              727-200 Advanced        NaN           NaN
# 72B             Boeing                 727-100 Mixed        72M            3J
# 72C             Boeing                 727-200 Mixed        72M            3J
# 72F             Boeing      727 Freighter (-100/200)        NaN           NaN
# 72M             Boeing                     727 Combi        NaN           NaN
# 72S             Boeing                  727-200 Adv.        NaN           NaN
# 72W             Boeing            727-200 (winglets)        727            3J
# 72X             Boeing             727-100 Freighter        72F            3J
# 72Y             Boeing             727-200 Freighter        72F            3J
# 731             Boeing                       737-100        737            2J
# 732             Boeing                       737-200        737            2J
# 733             Boeing                       737-300        737            2J
# 734             Boeing                       737-400        737            2J
# 735             Boeing                       737-500        737            2J
# 736             Boeing                       737-600        737            2J
# 737             Boeing                           737        NaN           NaN
# 738             Boeing                       737-800        737            2J
# 739             Boeing                       737-900        737            2J
# 73A             Boeing              737-200 Advanced        NaN           NaN
# 73C             Boeing            737-300 (winglets)        737            2J
# 73E             Boeing            737-500 (winglets)        737            2J
# 73F             Boeing                 737 Freighter        NaN           NaN
# ...                ...                           ...        ...           ...
# 74X             Boeing             747-200 Freighter        74F            4J
# 74Y             Boeing             747-400 Freighter        74F            4J
# 752             Boeing                       757-200        757            2J
# 753             Boeing                       757-300        757            2J
# 757             Boeing                           757        NaN           NaN
# 75F             Boeing                 757 Freighter        75F            2J
# 75M             Boeing                     757 Mixed        75M            2J
# 75T             Boeing            757-300 (winglets)        757            2J
# 75W             Boeing            757-200 (winglets)        757            2J
# 762             Boeing                       767-200        767            2J
# 763             Boeing                       767-300        767            2J
# 764             Boeing                       767-400        767            2J
# 767             Boeing                           767        NaN           NaN
# 76F             Boeing                 767 Freighter        NaN           NaN
# 76V             Boeing  767-300 (winglets) Freighter        76F            2J
# 76W             Boeing            767-300 (winglets)        767            2J
# 76X             Boeing             767-200 Freighter        76F            2J
# 76Y             Boeing             767-300 Freighter        76F            2J
# 772             Boeing                       777-200        777            2J
# 773             Boeing                       777-300        777            2J
# 777             Boeing                           777        NaN           NaN
# 77F             Boeing                 777 Freighter        NaN           NaN
# 77L             Boeing                     777-200LR        777            2J
# 77W             Boeing                     777-300ER        777            2J
# 77X             Boeing            777-200F Freighter        77F            2J
# 783             Boeing                         787-3        787            2J
# 787             Boeing                           787        NaN           NaN
# 788             Boeing                         787-8        787            2J
# 789             Boeing                         787-9        787            2J
# B72             Boeing                          720B        707            4J
#
#           icao_code  nb_engines aircraft_type
# iata_code
# 703            B703         4.0             J
# 707             NaN         NaN           NaN
# 70F            B703         4.0             J
# 70M            B703         4.0             J
# 717            B712         2.0             J
# 721            B721         3.0             J
# 722            B722         3.0             J
# 727             NaN         NaN           NaN
# 72A             NaN         NaN           NaN
# 72B            B721         3.0             J
# 72C            B722         3.0             J
# 72F             NaN         NaN           NaN
# 72M             NaN         NaN           NaN
# 72S             NaN         NaN           NaN
# 72W            B722         3.0             J
# 72X            B721         3.0             J
# 72Y            B722         3.0             J
# 731            B731         2.0             J
# 732            B732         2.0             J
# 733            B733         2.0             J
# 734            B734         2.0             J
# 735            B735         2.0             J
# 736            B736         2.0             J
# 737             NaN         NaN           NaN
# 738            B738         2.0             J
# 739            B739         2.0             J
# 73A             NaN         NaN           NaN
# 73C            B733         2.0             J
# 73E            B735         2.0             J
# 73F             NaN         NaN           NaN
# ...             ...         ...           ...
# 74X            B742         4.0             J
# 74Y            B744         4.0             J
# 752            B752         2.0             J
# 753            B753         2.0             J
# 757             NaN         NaN           NaN
# 75F            B752         2.0             J
# 75M            B752         2.0             J
# 75T            B753         2.0             J
# 75W            B752         2.0             J
# 762            B762         2.0             J
# 763            B763         2.0             J
# 764            B764         2.0             J
# 767             NaN         NaN           NaN
# 76F             NaN         NaN           NaN
# 76V            B763         2.0             J
# 76W            B763         2.0             J
# 76X            B762         2.0             J
# 76Y            B763         2.0             J
# 772            B77L         2.0             J
# 773            B773         2.0             J
# 777             NaN         NaN           NaN
# 77F             NaN         NaN           NaN
# 77L            B772         2.0             J
# 77W            B77W         2.0             J
# 77X            B772         2.0             J
# 783            B783         2.0             J
# 787             NaN         NaN           NaN
# 788            B788         2.0             J
# 789            B789         2.0             J
# B72            B720         4.0             J
#
# [93 rows x 7 columns]
# Bombardier
#           manufacturer           model iata_group iata_category icao_code  \
# iata_code
# CCX         Bombardier  Global Express        CCX            2J      GLEX
# CL3         Bombardier  Challenger 300        CL3            2J      CL30
# CS1         Bombardier   CSeries CS100        CSB            2J      ZZZZ
# CS3         Bombardier           CS300        CSB            2J      ZZZZ
#
#            nb_engines aircraft_type
# iata_code
# CCX               2.0             J
# CL3               2.0             J
# CS1               2.0             J
# CS3               2.0             J
# Britten Norman
#              manufacturer                    model iata_group iata_category  \
# iata_code
# BNI        Britten Norman         BN-2A/B Islander        BNI            2P
# BNT        Britten Norman  BN-2A Mk III Trislander        BNT            3P
#
#           icao_code  nb_engines aircraft_type
# iata_code
# BNI            BN2P         2.0             P
# BNT            TRIS         3.0             P
# CASA
#           manufacturer        model iata_group iata_category icao_code  \
# iata_code
# CS2               CASA  212 Aviocar        CS2            2T      C212
#
#            nb_engines aircraft_type
# iata_code
# CS2               2.0             T
# Canadair
#           manufacturer          model iata_group iata_category icao_code  \
# iata_code
# C9B           Canadair      CRJ 900NG        NaN           NaN       NaN
# CCJ           Canadair     Challenger        CCJ            2J      CL60
# CL4           Canadair          CL-44        NaN           NaN       NaN
# CR1           Canadair        CRJ 100        CRJ            2J      CRJ1
# CR2           Canadair        CRJ 200        CRJ            2J      CRJ2
# CR7           Canadair        CRJ 700        CRJ            2J      CRJ7
# CR9           Canadair        CRJ 900        CRJ            2J      CRJ9
# CRA           Canadair        CRJ 705        CRJ            2J      CRJ9
# CRF           Canadair  CRJ Freighter        CRF            2J      ZZZZ
# CRJ           Canadair            CRJ        NaN           NaN       NaN
# CRK           Canadair       CRJ 1000        CRJ            2J      CRJX
#
#            nb_engines aircraft_type
# iata_code
# C9B               NaN           NaN
# CCJ               2.0             J
# CL4               NaN           NaN
# CR1               2.0             J
# CR2               2.0             J
# CR7               2.0             J
# CR9               2.0             J
# CRA               2.0             J
# CRF               2.0             J
# CRJ               NaN           NaN
# CRK               2.0             J
# Cessna
#           manufacturer                           model iata_group  \
# iata_code
# CJ1             Cessna            500/501/525 Citation        CNJ
# CJ2             Cessna            550/551/552 Citation        CNJ
# CJ5             Cessna                    560 Citation        CNJ
# CJ6             Cessna                    650 Citation        CNJ
# CJ8             Cessna                    680 Citation        CNJ
# CJL             Cessna             560 XL/XLS Citation        CNJ
# CJM             Cessna            510 Mustang Citation        CNJ
# CN1             Cessna     Cessna single piston engine        CNA
# CN2             Cessna      Cessna twin piston engines        CNA
# CN7             Cessna                  750 Citation X        CN7
# CNA             Cessna           Cessna light aircraft        NaN
# CNC             Cessna  Cessna single turboprop engine        CNA
# CNF             Cessna                  208B Freighter        CNF
# CNJ             Cessna                        Citation        CNJ
# CNT             Cessna   Cessna twin turboprop engines        CNA
#
#           iata_category icao_code  nb_engines aircraft_type
# iata_code
# CJ1                  2J         *         2.0             J
# CJ2                  2J         *         2.0             J
# CJ5                  2J         *         2.0             J
# CJ6                  2J         *         2.0             J
# CJ8                  2J         *         2.0             J
# CJL                  2J         *         2.0             J
# CJM                  2J      C510         2.0             J
# CN1                  1P         *         1.0             P
# CN2                  2P         *         2.0             P
# CN7                  2J      C750         2.0             J
# CNA                 NaN       NaN         NaN           NaN
# CNC                  1T         *         1.0             T
# CNF                  2T         *         2.0             T
# CNJ                  2J         *         2.0             J
# CNT                  2T         *         2.0             T
# Comac
#           manufacturer      model iata_group iata_category icao_code  \
# iata_code
# C27              Comac  ARJ21-700        C21            2J      AJ27
#
#            nb_engines aircraft_type
# iata_code
# C27               2.0             J
# Convair
#           manufacturer                                     model iata_group  \
# iata_code
# CV2            Convair                                    CV-240        CVR
# CV4            Convair                       CV-440 Metropolitan        CVR
# CV5            Convair                                    CV-580        CVR
# CV6            Convair                                CV-600/640        NaN
# CVF            Convair  CV-240 / 440 / 580 / 600 / 640 Freighter        NaN
# CVR            Convair            CV-240 / 440 / 580 / 600 / 640        NaN
# CVV            Convair                          CV-240 Freighter        CVF
# CVX            Convair                          CV-440 Freighter        CVF
# CVY            Convair              CV-580 / 600 / 640 Freighter        CVF
#
#           iata_category icao_code  nb_engines aircraft_type
# iata_code
# CV2                  2P      CVLP         2.0             P
# CV4                  2P      CVLP         2.0             P
# CV5                  2T      CVLT         2.0             T
# CV6                 NaN       NaN         NaN           NaN
# CVF                 NaN       NaN         NaN           NaN
# CVR                 NaN       NaN         NaN           NaN
# CVV                  2P      CVLP         2.0             P
# CVX                  2P      CVLP         2.0             P
# CVY                  2T      CVLT         2.0             T
# Curtiss
#           manufacturer          model iata_group iata_category icao_code  \
# iata_code
# CWC            Curtiss  C-46 Commando        CWC            2P       C46
#
#            nb_engines aircraft_type
# iata_code
# CWC               2.0             P
# DAHER-SOCATA
#            manufacturer    model iata_group iata_category icao_code  \
# iata_code
# TBM        DAHER-SOCATA  TBM-700        TBM            1T      TBM7
#
#            nb_engines aircraft_type
# iata_code
# TBM               1.0             T
# Dassault
#           manufacturer                                  model iata_group  \
# iata_code
# AMD           Dassault                    FALCON 10 / 20 / 50        NaN
# D20           Dassault                     Falcon 2000/2000DX        DFL
# D2L           Dassault                  Falcon 2000EX/EASY/LX        DFL
# D9L           Dassault                           Falcon 900LX        DFL
# DF1           Dassault                          Falcon 10/100        DFL
# DF2           Dassault      Falcon 10 / 100 / 20 / 200 / 2000        DFL
# DF3           Dassault                        Falcon 50 / 900        NaN
# DF5           Dassault                         Falcon 50/50EX        DFL
# DF7           Dassault                              Falcon 7X        DFL
# DF9           Dassault  Falcon 900/900B/900C/900DX/900EX/EASY        DFL
# DFL           Dassault                                 Falcon        NaN
#
#           iata_category icao_code  nb_engines aircraft_type
# iata_code
# AMD                 NaN       NaN         NaN           NaN
# D20                  2J      F2TH         2.0             J
# D2L                  2J      F2TH         2.0             J
# D9L                  3J      F900         3.0             J
# DF1                  2J      FA10         2.0             J
# DF2                  2J      FA20         2.0             J
# DF3                 NaN       NaN         NaN           NaN
# DF5                  3J      FA50         3.0             J
# DF7                  3J      FA7X         3.0             J
# DF9                  3J      F900         3.0             J
# DFL                 NaN       NaN         NaN           NaN
# De Havilland
#            manufacturer         model iata_group iata_category icao_code  \
# iata_code
# DHD        De Havilland   DH.104 Dove        DHD            2P      DOVE
# DHH        De Havilland  DH.114 Heron        DHH            4P      HERN
#
#            nb_engines aircraft_type
# iata_code
# DHD               2.0             P
# DHH               4.0             P
# De Havilland Canada
#                   manufacturer                        model iata_group  \
# iata_code
# DH7        De Havilland Canada                 DHC-7 Dash 7        DH7
# DHB        De Havilland Canada  DHC-2 Beaver / Turbo Beaver        NaN
# DHC        De Havilland Canada                DHC-4 Caribou        DHC
# DHL        De Havilland Canada            DHC-3 Turbo Otter        DHO
# DHO        De Havilland Canada    DHC-3 Otter / Turbo Otter        NaN
# DHP        De Havilland Canada                 DHC-2 Beaver        DHB
# DHR        De Havilland Canada           DHC-2 Turbo-Beaver        DHB
# DHS        De Havilland Canada                  DHC-3 Otter        DHO
# DHT        De Havilland Canada             DHC-6 Twin Otter        DHT
#
#           iata_category icao_code  nb_engines aircraft_type
# iata_code
# DH7                  4T      DHC7         4.0             T
# DHB                 NaN       NaN         NaN           NaN
# DHC                  2P      DHC4         2.0             P
# DHL                  1T      DH3T         1.0             T
# DHO                 NaN       NaN         NaN           NaN
# DHP                  1P      DHC2         1.0             P
# DHR                  1T      DH2T         1.0             T
# DHS                  1P      DHC3         1.0             P
# DHT          Twin Otter        2T         NaN             T
# De Havilland Canada-Bombardier
#                              manufacturer                        model  \
# iata_code
# D4X        De Havilland Canada-Bombardier  DHC-8-400 Dash 8Q Freighter
# DH1        De Havilland Canada-Bombardier        DHC-8-100 Dash 8 / 8Q
# DH2        De Havilland Canada-Bombardier        DHC-8-200 Dash 8 / 8Q
# DH3        De Havilland Canada-Bombardier        DHC-8-300 Dash 8 / 8Q
# DH4        De Havilland Canada-Bombardier            DHC-8-400 Dash 8Q
# DH8        De Havilland Canada-Bombardier                 DHC-8 Dash 8
#
#           iata_group iata_category icao_code  nb_engines aircraft_type
# iata_code
# D4X              DHF            2T      DH8D         2.0             T
# DH1              DH8            2T      DH8A         2.0             T
# DH2              DH8            2T      DH8B         2.0             T
# DH3              DH8            2T      DH8C         2.0             T
# DH4              DH8            2T      DH8D         2.0             T
# DH8              NaN           NaN       NaN         NaN           NaN
# De Havilland-Bombardier
#                       manufacturer            model iata_group iata_category  \
# iata_code
# DHF        De Havilland-Bombardier  DHC-8 Freighter        000            00
#
#           icao_code  nb_engines aircraft_type
# iata_code
# DHF            0000         NaN           NaN
# Diamond Aircraft
#                manufacturer            model iata_group iata_category  \
# iata_code
# D42        Diamond Aircraft   DA42 Twin Star        D42            2P
#
#           icao_code  nb_engines aircraft_type
# iata_code
# D42            DA42         2.0             P
# Dornier
#           manufacturer   model iata_group iata_category icao_code  nb_engines  \
# iata_code
# D28            Dornier  Do 228        D28            2T      D228         2.0
# D38            Dornier  Do 328        D38            2T      D328         2.0
# FR3            Dornier  328JET        NaN           NaN       NaN         NaN
# FR4            Dornier  428JET        NaN           NaN       NaN         NaN
# FRJ            Dornier  328JET        FRJ            2J      J328         2.0
#
#           aircraft_type
# iata_code
# D28                   T
# D38                   T
# FR3                 NaN
# FR4                 NaN
# FRJ                   J
# Douglas
#           manufacturer                        model iata_group iata_category  \
# iata_code
# D3F            Douglas               DC-3 Freighter        D3F            2P
# D6F            Douglas          DC-6A/B/C Freighter        D6F            4P
# D85            Douglas                      DC-8-50        NaN           NaN
# D86            Douglas                      DC-8-61        NaN           NaN
# D87            Douglas                      DC-8-71        NaN           NaN
# D8A            Douglas                      DC-8-63        NaN           NaN
# D8B            Douglas                      DC-8-73        NaN           NaN
# D8F            Douglas               DC-8 Freighter        NaN           NaN
# D8L            Douglas                      DC-8-62        DC8            4J
# D8M            Douglas                   DC-8 Combi        D8M            4J
# D8Q            Douglas                      DC-8-72        DC8            4J
# D8T            Douglas            DC-8-50 Freighter        D8F            4J
# D8X            Douglas  DC-8-61 / 62 / 63 Freighter        D8F            4J
# D8Y            Douglas  DC-8-71 / 72 / 73 Freighter        D8F            4J
# D91            Douglas                      DC-9-10        DC9            2J
# D92            Douglas                      DC-9-20        DC9            2J
# D93            Douglas                      DC-9-30        DC9            2J
# D94            Douglas                      DC-9-40        DC9            2J
# D95            Douglas                      DC-9-50        DC9            2J
# D9C            Douglas            DC-9-30 Freighter        D9F            2J
# D9D            Douglas            DC-9-40 Freighter        D9F            2J
# D9F            Douglas               DC-9 Freighter        NaN           NaN
# D9X            Douglas            DC-9-10 Freighter        D9F            2J
# DC3            Douglas                         DC-3        DC3            2P
# DC4            Douglas                         DC-4        DC4            4P
# DC6            Douglas                       DC6A/B        DC6            4P
# DC8            Douglas                         DC-8        NaN           NaN
# DC9            Douglas                         DC-9        NaN           NaN
#
#           icao_code  nb_engines aircraft_type
# iata_code
# D3F             DC3         2.0             P
# D6F             DC6         4.0             P
# D85             NaN         NaN           NaN
# D86             NaN         NaN           NaN
# D87             NaN         NaN           NaN
# D8A             NaN         NaN           NaN
# D8B             NaN         NaN           NaN
# D8F             NaN         NaN           NaN
# D8L            DC86         4.0             J
# D8M            DC86         4.0             J
# D8Q            DC87         4.0             J
# D8T            DC85         4.0             J
# D8X            DC86         4.0             J
# D8Y            DC87         4.0             J
# D91            DC91         2.0             J
# D92            DC92         2.0             J
# D93            DC93         2.0             J
# D94            DC94         2.0             J
# D95            DC95         2.0             J
# D9C            DC93         2.0             J
# D9D            DC94         2.0             J
# D9F             NaN         NaN           NaN
# D9X            DC91         2.0             J
# DC3             DC3         2.0             P
# DC4             DC4         4.0             P
# DC6             DC6         4.0             P
# DC8             NaN         NaN           NaN
# DC9             NaN         NaN           NaN
# Eclipse
#           manufacturer        model iata_group iata_category icao_code  \
# iata_code
# EA5            Eclipse  Eclipse 500        EAC            2J      EA50
#
#            nb_engines aircraft_type
# iata_code
# EA5               2.0             J
# Embraer
#           manufacturer                        model iata_group iata_category  \
# iata_code
# E70            Embraer            EMB 170 / EMB 175        EMJ            2J
# E75            Embraer                      EMB 175        EMJ            2J
# E90            Embraer            EMB 190 / EMB 195        EMJ            2J
# E95            Embraer                      EMB 195        EMJ            2J
# EM2            Embraer             EMB 120 Brasilia        EM2            2T
# EMB            Embraer          EMB 110 Bandeirante        EMB            2T
# EMJ            Embraer            EMB 170 / EMB 190        NaN           NaN
# EP1            Embraer           EMB-500 Phenom 100        EPH            2J
# EP3            Embraer           EMB-505 Phenom 300        EPH            2J
# ER3            Embraer                      ERJ 135        ERJ            2J
# ER4            Embraer                      ERJ 145        ERJ            2J
# ERD            Embraer                      ERJ 140        ERJ            2J
# ERJ            Embraer  ERJ 135 / ERJ 140 / ERJ 145        NaN           NaN
#
#           icao_code  nb_engines aircraft_type
# iata_code
# E70            E170         2.0             J
# E75            E170         2.0             J
# E90            E190         2.0             J
# E95            E190         2.0             J
# EM2            E120         2.0             T
# EMB            E110         2.0             T
# EMJ             NaN         NaN           NaN
# EP1            E50P         2.0             J
# EP3            E55P         2.0             J
# ER3            E135         2.0             J
# ER4            E145         2.0             J
# ERD            E135         2.0             J
# ERJ             NaN         NaN           NaN
# Eurocopter
#           manufacturer                              model iata_group  \
# iata_code
# APH         Eurocopter      SA330 Puma / AS332 Super Puma        APH
# EC3         Eurocopter                              EC130        EC3
# NDE         Eurocopter  AS350 Ecureuil / AS355 Ecureuil 2        NDE
# NDH         Eurocopter          SA365C / SA365N Dauphin 2        NDH
#
#           iata_category icao_code  nb_engines aircraft_type
# iata_code
# APH                   H         *         NaN             H
# EC3                   H      EC30         NaN             H
# NDE                   H         *         NaN             H
# NDH                   H         *         NaN             H
# Fairchild-Hiller
#                manufacturer   model iata_group iata_category icao_code  \
# iata_code
# FK7        Fairchild-Hiller  FH-227        FK7            2T       F27
#
#            nb_engines aircraft_type
# iata_code
# FK7               2.0             T
# Fairchild-Swearingen
#                    manufacturer                                model  \
# iata_code
# SWF        Fairchild-Swearingen                      SA226 Freighter
# SWM        Fairchild-Swearingen  SA26 / SA226 / SA227 Metro / Merlin
#
#           iata_group iata_category icao_code  nb_engines aircraft_type
# iata_code
# SWF              SWF            2T         *         2.0             T
# SWM              SWM            2T         *         2.0             T
# Fokker
#           manufacturer                model iata_group iata_category  \
# ...
#
#           aircraft_type
# iata_code
# L4T                   T
# Learjet
#           manufacturer          model iata_group iata_category icao_code  \
# iata_code
# LRJ            Learjet  Gates Learjet        LRJ            2J         *
#
#            nb_engines aircraft_type
# iata_code
# LRJ               2.0             J
# Lockheed
#           manufacturer                                     model iata_group  \
# iata_code
# L10           Lockheed                            L-1011 Tristar        NaN
# L11           Lockheed  L-1011 1 / 50 / 100 / 150 / 200 / 250 Tr        L10
# L15           Lockheed                        L-1011 500 Tristar        L10
# L1F           Lockheed                  L-1011 Tristar Freighter        L1F
# L49           Lockheed                L-1049 Super Constellation        NaN
# LOE           Lockheed                             L-188 Electra        LOE
# LOF           Lockheed                   L-188 Electra Freighter        LOF
# LOH           Lockheed        L-182 / 282 / 382 (L-100) Hercules        LOH
# LOM           Lockheed                       L-188 Electra Mixed        NaN
#
#           iata_category icao_code  nb_engines aircraft_type
# iata_code
# L10                 NaN       NaN         NaN           NaN
# L11                  3J      L101         3.0             J
# L15                  3J      L101         3.0             J
# L1F                  3J      L101         3.0             J
# L49                 NaN       NaN         NaN           NaN
# LOE                  4T      L188         4.0             T
# LOF                  4T      L188         4.0             T
# LOH                  4T      C130         4.0             T
# LOM                 NaN       NaN         NaN           NaN
# MBB
#           manufacturer   model iata_group iata_category icao_code  nb_engines  \
# iata_code
# MBH                MBB  Bo 105        MBH             H      B105         NaN
#
#           aircraft_type
# iata_code
# MBH                   H
# MD Helicopters
#              manufacturer           model iata_group iata_category icao_code  \
# iata_code
# MD9        MD Helicopters  MD900 Explorer        MD9             H      EXPL
#
#            nb_engines aircraft_type
# iata_code
# MD9               NaN             H
# McDonnell Douglas
#                 manufacturer                    model iata_group  \
# iata_code
# D10        McDonnell Douglas                    DC-10        NaN
# D11        McDonnell Douglas              DC-10-10/15        D10
# D14        McDonnell Douglas                 DC-10-40        NaN
# D1C        McDonnell Douglas              DC-10-30/40        D10
# D1F        McDonnell Douglas          DC-10 Freighter        NaN
# D1M        McDonnell Douglas              DC-10 Combi        D1M
# D1X        McDonnell Douglas       DC-10-10 Freighter        D1F
# D1Y        McDonnell Douglas  DC-10-30 / 40 Freighter        D1F
# M11        McDonnell Douglas                    MD-11        M11
# M1F        McDonnell Douglas          MD-11 Freighter        M1F
# M1M        McDonnell Douglas              MD-11 Mixed        M1M
# M2F        McDonnell Douglas           MD82 Freighter        M2F
# M3F        McDonnell Douglas           MD83 Freighter        M3F
# M80        McDonnell Douglas                    MD-80        NaN
# M81        McDonnell Douglas                    MD-81        M80
# M82        McDonnell Douglas                    MD-82        M80
# M83        McDonnell Douglas                    MD-83        M80
# M87        McDonnell Douglas                    MD-87        M80
# M88        McDonnell Douglas                    MD-88        M80
# M8F        McDonnell Douglas           MD88 Freighter        M8F
# M90        McDonnell Douglas                    MD-90        M90
# M95        McDonnell Douglas                    MD-95        NaN
#
#           iata_category icao_code  nb_engines aircraft_type
# iata_code
# D10                 NaN       NaN         NaN           NaN
# D11                  3J      DC10         3.0             J
# D14                 NaN       NaN         NaN           NaN
# D1C                  3J      DC10         3.0             J
# D1F                 NaN       NaN         NaN           NaN
# D1M                  3J      DC10         3.0             J
# D1X                  3J      DC10         3.0             J
# D1Y                  3J      DC10         3.0             J
# M11                  3J      MD11         3.0             J
# M1F                  3J      MD11         3.0             J
# M1M                  3J      MD11         3.0             J
# M2F                  2J      MD82         2.0             J
# M3F                  2J      MD83         2.0             J
# M80                 NaN       NaN         NaN           NaN
# M81                  2J      MD81         2.0             J
# M82                  2J      MD82         2.0             J
# M83                  2J      MD83         2.0             J
# M87                  2J      MD87         2.0             J
# M88                  2J      MD88         2.0             J
# M8F                  2J      MD88         2.0             J
# M90                  2J      MD90         2.0             J
# M95                 NaN       NaN         NaN           NaN
# Mil
#           manufacturer                            model iata_group  \
# iata_code
# MIH                Mil  Mi-8 / Mi-17 / Mi-171 / Mil-172        MIH
#
#           iata_category icao_code  nb_engines aircraft_type
# iata_code
# MIH                   H       MI8         NaN             H
# Mitsubishi
#           manufacturer model iata_group iata_category icao_code  nb_engines  \
# iata_code
# MU2         Mitsubishi  Mu-2        MU2            2T       MU2         2.0
#
#           aircraft_type
# iata_code
# MU2                   T
# NAMC
#           manufacturer  model iata_group iata_category icao_code  nb_engines  \
# iata_code
# YS1               NAMC  YS-11        YS1            2T      YS11         2.0
#
#           aircraft_type
# iata_code
# YS1                   T
# Nord / SNCAN
#            manufacturer  model iata_group iata_category icao_code  nb_engines  \
# iata_code
# ND2        Nord / SNCAN  N.262        NaN           NaN       NaN         NaN
#
#           aircraft_type
# iata_code
# ND2                 NaN
# Partenavia
#           manufacturer model iata_group iata_category icao_code  nb_engines  \
# iata_code
# PN6         Partenavia  P.68        PN6            2P       P68         2.0
#
#           aircraft_type
# iata_code
# PN6                   P
# Piaggio Aero
#            manufacturer           model iata_group iata_category icao_code  \
# iata_code
# P18        Piaggio Aero  P180 Avanti II        P18            2T      P180
#
#            nb_engines aircraft_type
# iata_code
# P18               2.0             T
# Pilatus
#           manufacturer              model iata_group iata_category icao_code  \
# iata_code
# PL2            Pilatus              PC-12        PL2            1T      PC12
# PL6            Pilatus  PC-6 Turbo Porter        PL6            1T      PC6T
#
#            nb_engines aircraft_type
# iata_code
# PL2               1.0             T
# PL6               1.0             T
# Piper
#           manufacturer                         model iata_group iata_category  \
# iata_code
# PA1              Piper    Piper single piston engine        PAG            1P
# PA2              Piper     Piper twin piston engines        PAG            2P
# PAG              Piper          Piper light aircraft        NaN           NaN
# PAT              Piper  Piper twin turboprop engines        PAG            2T
#
#           icao_code  nb_engines aircraft_type
# iata_code
# PA1               *         1.0             P
# PA2               *         2.0             P
# PAG             NaN         NaN           NaN
# PAT               *         2.0             T
# Rockwell
#           manufacturer                      model iata_group iata_category  \
# iata_code
# ACD           Rockwell  Commander/Turbo Commander        NaN           NaN
# ACP           Rockwell                  Commander        ACD            2P
# ACT           Rockwell            Turbo Commander        ACD            2T
#
#           icao_code  nb_engines aircraft_type
# iata_code
# ACD             NaN         NaN           NaN
# ACP               *         2.0             P
# ACT               *         2.0             T
# Saab
#           manufacturer            model iata_group iata_category icao_code  \
# iata_code
# S20               Saab             2000        S20            2T      SB20
# SF3               Saab         SF340A/B        SF3            2T      SF34
# SFB               Saab           SF340B        SF3            2T      SF34
# SFF               Saab  SF340 Freighter        SFF            2T      SF34
#
#            nb_engines aircraft_type
# iata_code
# S20               2.0             T
# SF3               2.0             T
# SFB               2.0             T
# SFF               2.0             T
# Shaanxi
#           manufacturer model iata_group iata_category icao_code  nb_engines  \
# iata_code
# SY8            Shaanxi   Y-8        SY8            4T      AN12         4.0
#
#           aircraft_type
# iata_code
# SY8                   T
# Shorts
#           manufacturer         model iata_group iata_category icao_code  \
# iata_code
# SH3             Shorts        SD.330        SH3            2T      SH33
# SH6             Shorts        SD.360        SH6            2T      SH36
# SHB             Shorts  SC-5 Belfast        NaN           NaN       NaN
# SHS             Shorts   SC-7 Skyvan        SHS            2T       SC7
#
#            nb_engines aircraft_type
# iata_code
# SH3               2.0             T
# SH6               2.0             T
# SHB               NaN           NaN
# SHS               2.0             T
# Sikorsky
#           manufacturer  model iata_group iata_category icao_code  nb_engines  \
# iata_code
# S58           Sikorsky  S-58T        S58             H      S58T         NaN
# S61           Sikorsky   S-61        S61             H       S61         NaN
# S76           Sikorsky   S-76        S76             H       S76         NaN
#
#           aircraft_type
# iata_code
# S58                   H
# S61                   H
# S76                   H
# Sud-Est
#           manufacturer             model iata_group iata_category icao_code  \
# iata_code
# CRV            Sud-Est  SE.210 Caravelle        NaN           NaN       NaN
#
#            nb_engines aircraft_type
# iata_code
# CRV               NaN           NaN
# Sukhoi
#           manufacturer            model iata_group iata_category icao_code  \
# iata_code
# SU1             Sukhoi     Superjet 100        NaN           NaN       NaN
# SU7             Sukhoi  Superjet 100-75        SU1            2J      ZZZZ
# SU9             Sukhoi  Superjet 100-95        SU1            2J      SU95
#
#            nb_engines aircraft_type
# iata_code
# SU1               NaN           NaN
# SU7               2.0             J
# SU9               2.0             J
# Surface Equipment
#                 manufacturer        model iata_group iata_category icao_code  \
# iata_code
# BUS        Surface Equipment          Bus        BUS             S      0000
# LCH        Surface Equipment  Launch/Boat        LCH             S      0000
# LMO        Surface Equipment    Limousine        LMO             S      0000
# TRN        Surface Equipment        Train        TRN             S      0000
#
#            nb_engines aircraft_type
# iata_code
# BUS               NaN             S
# LCH               NaN             S
# LMO               NaN             S
# TRN               NaN             S
# Tupolev
#           manufacturer             model iata_group iata_category icao_code  \
# iata_code
# T20            Tupolev   Tu-204 / Tu-214        T20            2J      T204
# T2F            Tupolev  Tu-204 Freighter        T2F            2J      T204
# T34            Tupolev            Tu-334        T34            2J      T334
# TU3            Tupolev            Tu-134        TU3            2J      T134
# TU5            Tupolev            Tu-154        TU5            3J      T154
#
#            nb_engines aircraft_type
# iata_code
# T20               2.0             J
# T2F               2.0             J
# T34               2.0             J
# TU3               2.0             J
# TU5               3.0             J
# Vickers
#           manufacturer     model iata_group iata_category icao_code  \
# iata_code
# VCV            Vickers  Viscount        NaN           NaN       NaN
# VCX            Vickers     VC-10        NaN           NaN       NaN
#
#            nb_engines aircraft_type
# iata_code
# VCV               NaN           NaN
# VCX               NaN           NaN
# Xian
#           manufacturer        model iata_group iata_category icao_code  \
# iata_code
# MA6               Xian        MA-60        MA6            2T      AN24
# YN7               Xian  Yunshuji Y7        YN7            2T      AN24
#
#            nb_engines aircraft_type
# iata_code
# MA6               2.0             T
# YN7               2.0             T
# Yakovlev / Jakovlev
#                   manufacturer   model iata_group iata_category icao_code  \
# iata_code
# YK2        Yakovlev / Jakovlev  Yak 42        YK2            3J      YK42
# YK4        Yakovlev / Jakovlev  Yak 40        YK4            3J      YK40
#
#            nb_engines aircraft_type
# iata_code
# YK2               3.0             J
# YK4               3.0             J

# %%
groups['nb_engines']

# %%
for k, group in groups['nb_engines']:
    print type(group)
    break # Solo le echamos un ojo al primer grupo, los demas seran iguales.
# Out:
# <class 'pandas.core.series.Series'>

# %%
# When grouping, we specify a column or columns to group by, then 
# a column or columns to 'select' and then an aggregation or aggregations:

by_manufacturer = aircraft_bien.groupby('manufacturer')
engines_by_manufacturer = by_manufacturer['nb_engines']
avg_engines_per_manufacturer = engines_by_manufacturer.mean()

# %%
engine_stats = engines_by_manufacturer.agg(['mean', 'std'])
engine_stats
# Out:
#                                     mean       std
# manufacturer
# ATR                             2.000000  0.000000
# Aerospatiale / SNIAS            2.000000       NaN
# Agusta / AgustaWestland              NaN       NaN
# AgustaWestland                  2.000000       NaN
# Airbus                          2.413793  0.824502
# Aircraft Industries (LET)       2.000000       NaN
# Airtech                         2.000000       NaN
# Antonov                         3.200000  1.788854
# Antonow / Antonov               2.444444  0.881917
# Ayres                                NaN       NaN
# BAC                             2.000000  0.000000
# BAe                             3.200000  1.014185
# Beechcraft                      1.875000  0.353553
# Bell Helicopter                      NaN       NaN
# Boeing                          2.698630  0.908065
# Bombardier                      2.000000  0.000000
# Britten Norman                  2.500000  0.707107
# CASA                            2.000000       NaN
# Canadair                        2.000000  0.000000
# Cessna                          1.857143  0.363137
# Comac                           2.000000       NaN
# Convair                         2.000000  0.000000
# Curtiss                         2.000000       NaN
# DAHER-SOCATA                    1.000000       NaN
# Dassault                        2.500000  0.534522
# De Havilland                    3.000000  1.414214
# De Havilland Canada             1.666667  1.211060
# De Havilland Canada-Bombardier  2.000000  0.000000
# De Havilland-Bombardier              NaN       NaN
# Diamond Aircraft                2.000000       NaN
# ...                                  ...       ...
# Helio                           1.000000       NaN
# IAI                             2.000000       NaN
# Ilyushin                        3.714286  0.755929
# Junkers                         3.000000       NaN
# LET                             2.000000       NaN
# Learjet                         2.000000       NaN
# Lockheed                        3.500000  0.547723
# MBB                                  NaN       NaN
# MD Helicopters                       NaN       NaN
# McDonnell Douglas               2.470588  0.514496
# Mil                                  NaN       NaN
# Mitsubishi                      2.000000       NaN
# NAMC                            2.000000       NaN
# Nord / SNCAN                         NaN       NaN
# Partenavia                      2.000000       NaN
# Piaggio Aero                    2.000000       NaN
# Pilatus                         1.000000  0.000000
# Piper                           1.666667  0.577350
# Rockwell                        2.000000  0.000000
# Saab                            2.000000  0.000000
# Shaanxi                         4.000000       NaN
# Shorts                          2.000000  0.000000
# Sikorsky                             NaN       NaN
# Sud-Est                              NaN       NaN
# Sukhoi                          2.000000  0.000000
# Surface Equipment                    NaN       NaN
# Tupolev                         2.200000  0.447214
# Vickers                              NaN       NaN
# Xian                            2.000000  0.000000
# Yakovlev / Jakovlev             3.000000  0.000000
#
# [75 rows x 2 columns]

# %%
engine_stats.sort_values(by=['mean', 'std'], ascending=False).head(10)
# Out:
#                          mean       std
# manufacturer
# Shaanxi              4.000000       NaN
# Ilyushin             3.714286  0.755929
# Lockheed             3.500000  0.547723
# Antonov              3.200000  1.788854
# BAe                  3.200000  1.014185
# De Havilland         3.000000  1.414214
# Yakovlev / Jakovlev  3.000000  0.000000
# Junkers              3.000000       NaN
# Douglas              2.947368  1.025978
# Boeing               2.698630  0.908065

# %% [markdown]
# # Join
#
# As before, very similar to sql.

# %%
# We need to specify what column we'll use to join the values on, 
# or pandas will try to use the indexes, which in this case are not compatible

aircraft_bien.join(avg_engines_per_manufacturer, rsuffix="_mean")
# Out:
#                    manufacturer                                model  \
# iata_code
# 100                      Fokker                                  100
# 141                         BAe                              146-100
# 142                         BAe        BAE Systems 146-200 Passenger
# 143                         BAe                              146-300
# 146                         BAe                                  146
# 14F                         BAe  146 Freighter (-100/200/300QT & QC)
# 14X                         BAe          146 Freighter (-100QT & QC)
# 14Y                         BAe          146 Freighter (-200QT & QC)
# 14Z                         BAe          146 Freighter (-300QT & QC)
# 19D                      Airbus                                 A319
# 310                      Airbus                                 A310
# 312                      Airbus                             A310-200
# 313                      Airbus                             A310-300
# 318                      Airbus                                 A318
# 319                      Airbus                                 A319
# 31F                      Airbus                                A310F
# 31W                      Airbus                     A319 (Sharklets)
# 31X                      Airbus                            A310-200F
# 31Y                      Airbus                            A310-300F
# 320                      Airbus                         A320-100/200
# 321                      Airbus                         A321-100/200
# 32A                      Airbus                     A320 (sharklets)
# 32B                      Airbus                     A321 (sharklets)
# 32C                      Airbus                     A318 (sharklets)
# 32D                      Airbus                     A319 (sharklets)
# 32F                      Airbus                       A320 Freighter
# 32X                      Airbus                       A321 Freighter
# 330                      Airbus                                 A330
# 332                      Airbus                             A330-200
# 333                      Airbus                             A330-300
# ...                         ...                                  ...
# S76                    Sikorsky                                 S-76
# SF3                        Saab                             SF340A/B
# SFB                        Saab                               SF340B
# SFF                        Saab                      SF340 Freighter
# SH3                      Shorts                               SD.330
# SH6                      Shorts                               SD.360
# SHB                      Shorts                         SC-5 Belfast
# SHS                      Shorts                          SC-7 Skyvan
# SSC        Aerospatiale / SNIAS                             Concorde
# SU1                      Sukhoi                         Superjet 100
# SU7                      Sukhoi                      Superjet 100-75
# SU9                      Sukhoi                      Superjet 100-95
# SWF        Fairchild-Swearingen                      SA226 Freighter
# SWM        Fairchild-Swearingen  SA26 / SA226 / SA227 Metro / Merlin
# SY8                     Shaanxi                                  Y-8
# T20                     Tupolev                      Tu-204 / Tu-214
# T2F                     Tupolev                     Tu-204 Freighter
# T34                     Tupolev                               Tu-334
# TBM                DAHER-SOCATA                              TBM-700
# TRN           Surface Equipment                                Train
# TU3                     Tupolev                               Tu-134
# TU5                     Tupolev                               Tu-154
# VCV                     Vickers                             Viscount
# VCX                     Vickers                                VC-10
# WWP                         IAI                        1124 Westwind
# YK2         Yakovlev / Jakovlev                               Yak 42
# YK4         Yakovlev / Jakovlev                               Yak 40
# YN2               HAMC / Harbin                                  Y12
# YN7                        Xian                          Yunshuji Y7
# YS1                        NAMC                                YS-11
#
#           iata_group iata_category icao_code  nb_engines aircraft_type  \
# iata_code
# 100              100            2J      F100         2.0             J
# 141              146            4J      B461         4.0             J
# 142              146            4J      B462         4.0             J
# 143              146            4J      B463         4.0             J
# 146              NaN           NaN       NaN         NaN           NaN
# 14F              NaN           NaN       NaN         NaN           NaN
# 14X              14F            4J      B461         4.0             J
# 14Y              14F            4J      B462         4.0             J
# 14Z              14F            4J      B463         4.0             J
# 19D              NaN           NaN       NaN         NaN           NaN
# 310              NaN           NaN       NaN         NaN           NaN
# 312              310            2J      A310         2.0             J
# 313              310            2J      A310         2.0             J
# 318              32S            2J      A318         2.0             J
# 319              32S            2J      A319         2.0             J
# 31F              NaN           NaN       NaN         NaN           NaN
# 31W              NaN           NaN       NaN         NaN           NaN
# 31X              31F            2J      A310         2.0             J
# 31Y              31F            2J      A310         2.0             J
# 320              32S            2J      A320         2.0             J
# 321              32S            2J      A321         2.0             J
# 32A              32S            2J      A320         2.0             J
# 32B              32S            2J      A321         2.0             J
# 32C              NaN           NaN       NaN         NaN           NaN
# 32D              NaN           NaN       NaN         NaN           NaN
# 32F              32F            2J      A320         2.0             J
# 32X              32X            2J      A321         2.0             J
# 330              NaN           NaN       NaN         NaN           NaN
# 332              330            2J      A332         2.0             J
# 333              330            2J      A333         2.0             J
# ...              ...           ...       ...         ...           ...
# S76              S76             H       S76         NaN             H
# SF3              SF3            2T      SF34         2.0             T
# SFB              SF3            2T      SF34         2.0             T
# SFF              SFF            2T      SF34         2.0             T
# SH3              SH3            2T      SH33         2.0             T
# SH6              SH6            2T      SH36         2.0             T
# SHB              NaN           NaN       NaN         NaN           NaN
# SHS              SHS            2T       SC7         2.0             T
# SSC              NaN           NaN       NaN         NaN           NaN
# SU1              NaN           NaN       NaN         NaN           NaN
# SU7              SU1            2J      ZZZZ         2.0             J
# SU9              SU1            2J      SU95         2.0             J
# SWF              SWF            2T         *         2.0             T
# SWM              SWM            2T         *         2.0             T
# SY8              SY8            4T      AN12         4.0             T
# T20              T20            2J      T204         2.0             J
# T2F              T2F            2J      T204         2.0             J
# T34              T34            2J      T334         2.0             J
# TBM              TBM            1T      TBM7         1.0             T
# TRN              TRN             S      0000         NaN             S
# TU3              TU3            2J      T134         2.0             J
# TU5              TU5            3J      T154         3.0             J
# VCV              NaN           NaN       NaN         NaN           NaN
# VCX              NaN           NaN       NaN         NaN           NaN
# WWP              WWP            2J      WW24         2.0             J
# YK2              YK2            3J      YK42         3.0             J
# YK4              YK4            3J      YK40         3.0             J
# YN2              YN2            2T       Y12         2.0             T
# YN7              YN7            2T      AN24         2.0             T
# YS1              YS1            2T      YS11         2.0             T
#
#            nb_engines_mean
# iata_code
# 100                    NaN
# 141                    NaN
# 142                    NaN
# 143                    NaN
# 146                    NaN
# 14F                    NaN
# 14X                    NaN
# 14Y                    NaN
# 14Z                    NaN
# 19D                    NaN
# 310                    NaN
# 312                    NaN
# 313                    NaN
# 318                    NaN
# 319                    NaN
# 31F                    NaN
# 31W                    NaN
# 31X                    NaN
# 31Y                    NaN
# 320                    NaN
# 321                    NaN
# 32A                    NaN
# 32B                    NaN
# 32C                    NaN
# 32D                    NaN
# 32F                    NaN
# 32X                    NaN
# 330                    NaN
# 332                    NaN
# 333                    NaN
# ...                    ...
# S76                    NaN
# SF3                    NaN
# SFB                    NaN
# SFF                    NaN
# SH3                    NaN
# SH6                    NaN
# SHB                    NaN
# SHS                    NaN
# SSC                    NaN
# SU1                    NaN
# SU7                    NaN
# SU9                    NaN
# SWF                    NaN
# SWM                    NaN
# SY8                    NaN
# T20                    NaN
# T2F                    NaN
# T34                    NaN
# TBM                    NaN
# TRN                    NaN
# TU3                    NaN
# TU5                    NaN
# VCV                    NaN
# VCX                    NaN
# WWP                    NaN
# YK2                    NaN
# YK4                    NaN
# YN2                    NaN
# YN7                    NaN
# YS1                    NaN
#
# [457 rows x 8 columns]

# %%
aircraft_bien.join(avg_engines_per_manufacturer, rsuffix="_mean", on='manufacturer')
# Out:
#                    manufacturer                                model  \
# iata_code
# 100                      Fokker                                  100
# 141                         BAe                              146-100
# 142                         BAe        BAE Systems 146-200 Passenger
# 143                         BAe                              146-300
# 146                         BAe                                  146
# 14F                         BAe  146 Freighter (-100/200/300QT & QC)
# 14X                         BAe          146 Freighter (-100QT & QC)
# 14Y                         BAe          146 Freighter (-200QT & QC)
# 14Z                         BAe          146 Freighter (-300QT & QC)
# 19D                      Airbus                                 A319
# 310                      Airbus                                 A310
# 312                      Airbus                             A310-200
# 313                      Airbus                             A310-300
# 318                      Airbus                                 A318
# 319                      Airbus                                 A319
# 31F                      Airbus                                A310F
# 31W                      Airbus                     A319 (Sharklets)
# 31X                      Airbus                            A310-200F
# 31Y                      Airbus                            A310-300F
# 320                      Airbus                         A320-100/200
# 321                      Airbus                         A321-100/200
# 32A                      Airbus                     A320 (sharklets)
# 32B                      Airbus                     A321 (sharklets)
# 32C                      Airbus                     A318 (sharklets)
# 32D                      Airbus                     A319 (sharklets)
# 32F                      Airbus                       A320 Freighter
# 32X                      Airbus                       A321 Freighter
# 330                      Airbus                                 A330
# 332                      Airbus                             A330-200
# 333                      Airbus                             A330-300
# ...                         ...                                  ...
# S76                    Sikorsky                                 S-76
# SF3                        Saab                             SF340A/B
# SFB                        Saab                               SF340B
# SFF                        Saab                      SF340 Freighter
# SH3                      Shorts                               SD.330
# SH6                      Shorts                               SD.360
# SHB                      Shorts                         SC-5 Belfast
# SHS                      Shorts                          SC-7 Skyvan
# SSC        Aerospatiale / SNIAS                             Concorde
# SU1                      Sukhoi                         Superjet 100
# SU7                      Sukhoi                      Superjet 100-75
# SU9                      Sukhoi                      Superjet 100-95
# SWF        Fairchild-Swearingen                      SA226 Freighter
# SWM        Fairchild-Swearingen  SA26 / SA226 / SA227 Metro / Merlin
# SY8                     Shaanxi                                  Y-8
# T20                     Tupolev                      Tu-204 / Tu-214
# T2F                     Tupolev                     Tu-204 Freighter
# T34                     Tupolev                               Tu-334
# TBM                DAHER-SOCATA                              TBM-700
# TRN           Surface Equipment                                Train
# TU3                     Tupolev                               Tu-134
# TU5                     Tupolev                               Tu-154
# VCV                     Vickers                             Viscount
# VCX                     Vickers                                VC-10
# WWP                         IAI                        1124 Westwind
# YK2         Yakovlev / Jakovlev                               Yak 42
# YK4         Yakovlev / Jakovlev                               Yak 40
# YN2               HAMC / Harbin                                  Y12
# YN7                        Xian                          Yunshuji Y7
# YS1                        NAMC                                YS-11
#
#           iata_group iata_category icao_code  nb_engines aircraft_type  \
# iata_code
# 100              100            2J      F100         2.0             J
# 141              146            4J      B461         4.0             J
# 142              146            4J      B462         4.0             J
# 143              146            4J      B463         4.0             J
# 146              NaN           NaN       NaN         NaN           NaN
# 14F              NaN           NaN       NaN         NaN           NaN
# 14X              14F            4J      B461         4.0             J
# 14Y              14F            4J      B462         4.0             J
# 14Z              14F            4J      B463         4.0             J
# 19D              NaN           NaN       NaN         NaN           NaN
# 310              NaN           NaN       NaN         NaN           NaN
# 312              310            2J      A310         2.0             J
# 313              310            2J      A310         2.0             J
# 318              32S            2J      A318         2.0             J
# 319              32S            2J      A319         2.0             J
# 31F              NaN           NaN       NaN         NaN           NaN
# 31W              NaN           NaN       NaN         NaN           NaN
# 31X              31F            2J      A310         2.0             J
# 31Y              31F            2J      A310         2.0             J
# 320              32S            2J      A320         2.0             J
# 321              32S            2J      A321         2.0             J
# 32A              32S            2J      A320         2.0             J
# 32B              32S            2J      A321         2.0             J
# 32C              NaN           NaN       NaN         NaN           NaN
# 32D              NaN           NaN       NaN         NaN           NaN
# 32F              32F            2J      A320         2.0             J
# 32X              32X            2J      A321         2.0             J
# 330              NaN           NaN       NaN         NaN           NaN
# 332              330            2J      A332         2.0             J
# 333              330            2J      A333         2.0             J
# ...              ...           ...       ...         ...           ...
# S76              S76             H       S76         NaN             H
# SF3              SF3            2T      SF34         2.0             T
# SFB              SF3            2T      SF34         2.0             T
# SFF              SFF            2T      SF34         2.0             T
# SH3              SH3            2T      SH33         2.0             T
# SH6              SH6            2T      SH36         2.0             T
# SHB              NaN           NaN       NaN         NaN           NaN
# SHS              SHS            2T       SC7         2.0             T
# SSC              NaN           NaN       NaN         NaN           NaN
# SU1              NaN           NaN       NaN         NaN           NaN
# SU7              SU1            2J      ZZZZ         2.0             J
# SU9              SU1            2J      SU95         2.0             J
# SWF              SWF            2T         *         2.0             T
# SWM              SWM            2T         *         2.0             T
# SY8              SY8            4T      AN12         4.0             T
# T20              T20            2J      T204         2.0             J
# T2F              T2F            2J      T204         2.0             J
# T34              T34            2J      T334         2.0             J
# TBM              TBM            1T      TBM7         1.0             T
# TRN              TRN             S      0000         NaN             S
# TU3              TU3            2J      T134         2.0             J
# TU5              TU5            3J      T154         3.0             J
# VCV              NaN           NaN       NaN         NaN           NaN
# VCX              NaN           NaN       NaN         NaN           NaN
# WWP              WWP            2J      WW24         2.0             J
# YK2              YK2            3J      YK42         3.0             J
# YK4              YK4            3J      YK40         3.0             J
# YN2              YN2            2T       Y12         2.0             T
# YN7              YN7            2T      AN24         2.0             T
# YS1              YS1            2T      YS11         2.0             T
#
#            nb_engines_mean
# iata_code
# 100               2.000000
# 141               3.200000
# 142               3.200000
# 143               3.200000
# 146               3.200000
# 14F               3.200000
# 14X               3.200000
# 14Y               3.200000
# 14Z               3.200000
# 19D               2.413793
# 310               2.413793
# 312               2.413793
# 313               2.413793
# 318               2.413793
# 319               2.413793
# 31F               2.413793
# 31W               2.413793
# 31X               2.413793
# 31Y               2.413793
# 320               2.413793
# 321               2.413793
# 32A               2.413793
# 32B               2.413793
# 32C               2.413793
# 32D               2.413793
# 32F               2.413793
# 32X               2.413793
# 330               2.413793
# 332               2.413793
# 333               2.413793
# ...                    ...
# S76                    NaN
# SF3               2.000000
# SFB               2.000000
# SFF               2.000000
# SH3               2.000000
# SH6               2.000000
# SHB               2.000000
# SHS               2.000000
# SSC               2.000000
# SU1               2.000000
# SU7               2.000000
# SU9               2.000000
# SWF               2.000000
# SWM               2.000000
# SY8               4.000000
# T20               2.200000
# T2F               2.200000
# T34               2.200000
# TBM               1.000000
# TRN                    NaN
# TU3               2.200000
# TU5               2.200000
# VCV                    NaN
# VCX                    NaN
# WWP               2.000000
# YK2               3.000000
# YK4               3.000000
# YN2               2.000000
# YN7               2.000000
# YS1               2.000000
#
# [457 rows x 8 columns]
